# %% [markdown]
# # Assignment 2

# %% [markdown]
# 1.What are the two values of the Boolean data type? How do you write them?
# #### Solution:
# #### The two values of boolean data type is True and false which in some cases can be represented in the form of 0 and 1.
# #### We write them as True and False with T and F being in the upper case.
#
#
#
#
#
#
# 2. What are the three different types of Boolean operators?
# #### Solution:
# #### The 3 types of boolean operators are AND, OR and NOT.
#
#
#
#
#
#
#
# 3. Make a list of each Boolean operator's truth tables (i.e. every possible combination of Boolean values for the operator and what it evaluate ).
# #### Solution:
# #### ---> For AND operator:
#         True and True = True
#         True and False = False
#         False and True = False
#         False and False = False
# #### ---> For OR operator:
#         True or True = True
#         True or False = True
#         False or True = True
#         False or False = False
# #### ---> For NOT operator:
#         not True = False
#         not False = True
#
#
#
# 4. What are the values of the following expressions?
# #### (5 > 4) and (3 == 5)
# #### not (5 > 4)
# #### (5 > 4) or (3 == 5)
# #### not ((5 > 4) or (3 == 5))
# #### (True and True) and (True == False)
# #### (not False) or (not True)
# #### Solution:
# - False
# - False
# - True
# - False
# - True
#
#
#
# 5. What are the six comparison operators?
# #### Solution:
# #### The six comparison operators are-
# #### > greater than
# #### < less than
# #### >= grater that or equal to
# #### <= less than or equal to
# #### != not equal to
# #### == equal to
#
#
#
# 6. How do you tell the difference between the equal to and assignment operators?Describe a condition and when you would use one.
# #### Solution:
# #### The difference between equal to and assignment operator is for equal to we use double == and for assignment operator we use single =.
# #### we use assignment operator when we want to assign a value to the variable and equal to is used when we need to find like values.
#
#
#
#
#
# 7. Identify the three blocks in this code:
# #### spam = 0
# #### if spam == 10:
# #### print('eggs')
# #### if spam > 5:
# #### print('bacon')
# #### else:
# #### print('ham')
# #### print('spam')
# #### print('spam')
#
# #### Solution:
# #### spam = 0
# #### if spam == 10:      1st Block of code
# #### print('eggs')
# ---------------------------------
# #### if spam > 5:        2nd Block of code
# #### print('bacon')
# ---------------------------------
# #### else:
# #### print('ham')
# #### print('spam')       3rd Block of code
# #### print('spam')

# %%
# 8. Write code that prints Hello if 1 is stored in spam, 
#    prints Howdy if 2 is stored in spam, and prints Greetings! if anything else is stored in spam.

#Solution:

spam = int(input('Please enter any number.'))

if spam == 1:
    print("Hello")
elif spam == 2:
    print("Howdy")
else:
    print("Greetings!")
# Out:
# Please enter any number.100
# Greetings!

# %% [markdown]
# 9.If your programme is stuck in an endless loop, what keys you’ll press?
# #### Solution:
# - By holding Ctrl key and pressing C key simultaneously it will send an interrrupt signal.
# - Anothe way is to click on kernel and than click on Interupt in notebook.
#
#
# 10. How can you tell the difference between break and continue?
# #### Solution:
# #### The Difference between break and continue is: in loops when we want to itterate through the set of elements and we need to stop iterating after certain condition is met at this time we will use break. on other hand we use continue in loops you want a particular iteration to be skipped when that particular condition is met.
#
#
#
#
# 11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?
# #### Solution:
# #### In for loops there is no difference between range(10), range(0, 10), and range(0, 10, 1) the produce the same result however when range(10) is written it takes 0 as lower bound and step size as 1 by default and when range(0,10) is written it takes step size as 1 by default.

# %%
# 12. Write a short program that prints the numbers 1 to 10 using a for loop. 
#     Then write an equivalent program that prints the numbers 1 to 10 using a while loop.

# Solution:
# i) prints the numbers 1 to 10 using a for loop:

for i in range(1,11):
    print(i)

# ii) Then write an equivalent program that prints the numbers 1 to 10 using a while loop
num = 1
while num <= 10:
    print(num)
    num = num + 1

# %% [markdown]
# 13. If you had a function named bacon() inside a module named spam, how would you call it after importing spam?
# #### Solution:
# #### spam.bacon()
